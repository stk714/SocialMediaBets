# %%
# Initial imports
import os
import requests
import json
import pandas as pd
from dotenv import load_dotenv
from pathlib import Path

# %%
load_dotenv()
# Out:
# Python-dotenv could not parse statement starting at line 1
# True

# %%
api_key = os.getenv("RAPID_API_KEY")

# %%
url = "https://yahoo-finance-low-latency.p.rapidapi.com/v8/finance/spark"

querystring = {"symbols":"AAPL,BAC,GE","range":"5y","interval":"1d"}

headers = {
    'x-rapidapi-key': api_key,
    'x-rapidapi-host': "yahoo-finance-low-latency.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"Invalid API key. Go to https:\/\/docs.rapidapi.com\/docs\/keys for more info."}

# %%
yahoo_finance_data = response.json()

# %%
yahoo_finance_df = pd.DataFrame(yahoo_finance_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-b86dd156bf34> in <module>
# ----> 1 yahoo_finance_df = pd.DataFrame(yahoo_finance_data)
#
# ~/miniforge3/envs/dev/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~/miniforge3/envs/dev/lib/python3.8/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~/miniforge3/envs/dev/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# ~/miniforge3/envs/dev/lib/python3.8/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     389
#     390         if not indexes and not raw_lengths:
# --> 391             raise ValueError("If using all scalar values, you must pass an index")
#     392
#     393         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %%
df = yahoo_finance_df.transform

# %%
yahoo_finance_df

# %%
yahoo_finance_df.set_index("timestamp")
